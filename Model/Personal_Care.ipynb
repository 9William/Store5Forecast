# %% [markdown]
# #Library

# %%
#Pip Install
#!pip install --upgrade statsmodels
#!pip install prophet

# %%
# Import library yang akan digunakan
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time

from prophet import Prophet
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# Import min-max scaling function
from sklearn.preprocessing import MinMaxScaler


# Import keras lstm model
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Bidirectional, GRU, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from keras.preprocessing.sequence import TimeseriesGenerator

# Metrics
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# #Pre Processing Data

# %%
df_train = pd.read_csv('store5.csv')
df_train
# Out:
#             id        date  store_nbr                      family     sales  \
# 0         1452  2013-01-01          5                  AUTOMOTIVE     0.000
# 1         1453  2013-01-01          5                   BABY CARE     0.000
# 2         1454  2013-01-01          5                      BEAUTY     0.000
# 3         1455  2013-01-01          5                   BEVERAGES     0.000
# 4         1456  2013-01-01          5                       BOOKS     0.000
# ...        ...         ...        ...                         ...       ...
# 55567  3000586  2017-08-15          5                     POULTRY   241.011
# 55568  3000587  2017-08-15          5              PREPARED FOODS    52.121
# 55569  3000588  2017-08-15          5                     PRODUCE  1357.823
# 55570  3000589  2017-08-15          5  SCHOOL AND OFFICE SUPPLIES     0.000
# 55571  3000590  2017-08-15          5                     SEAFOOD     9.669
#
#        onpromotion  dcoilwtico
# 0                0         NaN
# 1                0         NaN
# 2                0         NaN
# 3                0         NaN
# 4                0         NaN
# ...            ...         ...
# 55567            1       47.57
# 55568            0       47.57
# 55569            4       47.57
# 55570            0       47.57
# 55571            0       47.57
#
# [55572 rows x 7 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55572 entries, 0 to 55571
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           55572 non-null  int64
#  1   date         55572 non-null  object
#  2   store_nbr    55572 non-null  int64
#  3   family       55572 non-null  object
#  4   sales        55572 non-null  float64
#  5   onpromotion  55572 non-null  int64
#  6   dcoilwtico   38379 non-null  float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 3.0+ MB

# %%
# Check for missing values
df_train.isnull().sum()
# Out:
# id                 0
# date               0
# store_nbr          0
# family             0
# sales              0
# onpromotion        0
# dcoilwtico     17193
# dtype: int64

# %%
# hapus kolom id dan store_nbr
df_train.drop(['id', 'store_nbr'], axis=1, inplace=True)
# Mengubah tipe data kolom date menjadi datetime
df_train['date'] = pd.to_datetime(df_train['date'])
# Mengurutkan data berdasarkan tanggal
df_train = df_train.set_index('date')
df_train
# Out:
#                                 family     sales  onpromotion  dcoilwtico
# date
# 2013-01-01                  AUTOMOTIVE     0.000            0         NaN
# 2013-01-01                   BABY CARE     0.000            0         NaN
# 2013-01-01                      BEAUTY     0.000            0         NaN
# 2013-01-01                   BEVERAGES     0.000            0         NaN
# 2013-01-01                       BOOKS     0.000            0         NaN
# ...                                ...       ...          ...         ...
# 2017-08-15                     POULTRY   241.011            1       47.57
# 2017-08-15              PREPARED FOODS    52.121            0       47.57
# 2017-08-15                     PRODUCE  1357.823            4       47.57
# 2017-08-15  SCHOOL AND OFFICE SUPPLIES     0.000            0       47.57
# 2017-08-15                     SEAFOOD     9.669            0       47.57
#
# [55572 rows x 4 columns]

# %%
# Check  value
df_train['family'].value_counts()
# Out:
# AUTOMOTIVE                    1684
# HOME APPLIANCES               1684
# SCHOOL AND OFFICE SUPPLIES    1684
# PRODUCE                       1684
# PREPARED FOODS                1684
# POULTRY                       1684
# PLAYERS AND ELECTRONICS       1684
# PET SUPPLIES                  1684
# PERSONAL CARE                 1684
# MEATS                         1684
# MAGAZINES                     1684
# LIQUOR,WINE,BEER              1684
# LINGERIE                      1684
# LAWN AND GARDEN               1684
# LADIESWEAR                    1684
# HOME CARE                     1684
# HOME AND KITCHEN II           1684
# BABY CARE                     1684
# HOME AND KITCHEN I            1684
# HARDWARE                      1684
# GROCERY II                    1684
# GROCERY I                     1684
# FROZEN FOODS                  1684
# EGGS                          1684
# DELI                          1684
# DAIRY                         1684
# CLEANING                      1684
# CELEBRATION                   1684
# BREAD/BAKERY                  1684
# BOOKS                         1684
# BEVERAGES                     1684
# BEAUTY                        1684
# SEAFOOD                       1684
# Name: family, dtype: int64

# %%
# Total penjualan per family dengan format yang mudah dilihat
pd.options.display.float_format = '{:,.0f}'.format

df_train.groupby('family')['sales'].sum().sort_values(ascending=False)
# Out:
# family
# GROCERY I                    5,262,682
# BEVERAGES                    2,533,831
# CLEANING                     1,667,748
# PRODUCE                      1,653,582
# DAIRY                          871,283
# BREAD/BAKERY                   642,855
# MEATS                          477,104
# PERSONAL CARE                  450,166
# POULTRY                        419,630
# DELI                           415,271
# FROZEN FOODS                   269,669
# HOME CARE                      239,283
# EGGS                           190,851
# PREPARED FOODS                 147,991
# LIQUOR,WINE,BEER               110,414
# HOME AND KITCHEN II             37,238
# GROCERY II                      33,241
# LINGERIE                        31,561
# HOME AND KITCHEN I              30,107
# CELEBRATION                     26,176
# SEAFOOD                         22,359
# LADIESWEAR                      14,813
# AUTOMOTIVE                       9,194
# BEAUTY                           8,684
# PLAYERS AND ELECTRONICS          8,024
# MAGAZINES                        6,569
# LAWN AND GARDEN                  4,970
# PET SUPPLIES                     3,199
# HARDWARE                         1,725
# HOME APPLIANCES                    926
# SCHOOL AND OFFICE SUPPLIES         813
# BOOKS                              230
# BABY CARE                          215
# Name: sales, dtype: float64

# %%
# Total penjualan per family dengan format yang mudah dilihat
pd.options.display.float_format = '{:,.0f}'.format

df_train.groupby('family')['onpromotion'].sum().sort_values(ascending=False)
# Out:
# family
# GROCERY I                     37323
# PRODUCE                       24483
# BEVERAGES                     18413
# CLEANING                      12786
# DELI                          12448
# DAIRY                         10580
# MEATS                          6669
# PERSONAL CARE                  4547
# EGGS                           4440
# POULTRY                        4199
# BREAD/BAKERY                   3347
# HOME CARE                      3335
# FROZEN FOODS                   1953
# LIQUOR,WINE,BEER               1041
# HOME AND KITCHEN I              924
# SEAFOOD                         881
# HOME AND KITCHEN II             690
# PREPARED FOODS                  416
# BEAUTY                          261
# CELEBRATION                     206
# LAWN AND GARDEN                 157
# SCHOOL AND OFFICE SUPPLIES       77
# GROCERY II                       60
# LINGERIE                         57
# PET SUPPLIES                     42
# AUTOMOTIVE                       19
# PLAYERS AND ELECTRONICS           9
# LADIESWEAR                        3
# BABY CARE                         2
# HARDWARE                          1
# MAGAZINES                         1
# HOME APPLIANCES                   0
# BOOKS                             0
# Name: onpromotion, dtype: int64

# %% [markdown]
# #Visualisasi data

# %%
# Ambil data penjualan untuk family persC
persC = df_train['family']=='PERSONAL CARE'
persC = df_train[persC]
persC
# Out:
#                    family  sales  onpromotion  dcoilwtico
# date
# 2013-01-01  PERSONAL CARE      0            0         NaN
# 2013-01-02  PERSONAL CARE    427            0          93
# 2013-01-03  PERSONAL CARE    312            0          93
# 2013-01-04  PERSONAL CARE    265            0          93
# 2013-01-05  PERSONAL CARE    330            0         NaN
# ...                   ...    ...          ...         ...
# 2017-08-11  PERSONAL CARE    204            9          49
# 2017-08-12  PERSONAL CARE    159           12         NaN
# 2017-08-13  PERSONAL CARE    269           10         NaN
# 2017-08-14  PERSONAL CARE    196           10          48
# 2017-08-15  PERSONAL CARE    183            9          48
#
# [1684 rows x 4 columns]

# %%
plt.figure(figsize=(20,6))
sns.set(style='whitegrid')

sns.lineplot(data=persC, x='date', y='onpromotion', label='onpromotion')
plt.title('Pergerakan Promotion')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.set(style='whitegrid')

sns.lineplot(data=persC, x='date', y='dcoilwtico', label='dcoilwtico')
plt.title('Pergerakan Minyak')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# Melihat pergerakan penjualan, onpromotion dan minyak pada family persC
plt.figure(figsize=(20,6))
sns.set(style='whitegrid')
sns.lineplot(data=persC, x='date', y='sales', label='sales')
sns.lineplot(data=persC, x='date', y='onpromotion', label='onpromotion')
sns.lineplot(data=persC, x='date', y='dcoilwtico', label='dcoilwtico')
plt.title('Penjualan dan Onpromotion pada Family persC')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
#Mengubah index data menjadi tanggal 2016 2017
#persC = persC['2016':'2017']

# %%
# Melihat kembali penjualan dan onpromotion pada family persC
plt.figure(figsize=(20,6))
sns.set(style='whitegrid')
sns.lineplot(data=persC, x='date', y='sales', label='sales')
sns.lineplot(data=persC, x='date', y='onpromotion', label='onpromotion')
sns.lineplot(data=persC, x='date', y='dcoilwtico', label='dcoilwtico')
plt.title('Penjualan dan Onpromotion pada Family persC')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
corr_matrix = df_train.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap Correlation')
plt.show()
# Out:
# <ipython-input-19-99c40dc92ed5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df_train.corr()

# %%
# Decompose data transactions
plot_decompose = seasonal_decompose(persC['sales'], model='additive', period=30)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(20, 10))
plot_decompose.observed.plot(ax=ax1)
plot_decompose.trend.plot(ax=ax2)
plot_decompose.seasonal.plot(ax=ax3)
plot_decompose.resid.plot(ax=ax4)
# Out:
# <Axes: xlabel='date'>

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log
result = adfuller(persC['sales'].dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -4.236552
# p-value: 0.000571

# %%
# Plot ACF dan PACF
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
fig, ax = plt.subplots(2, 3, figsize=(25, 10))

ax[0, 0].set_title('Original Series')
ax[0, 0].plot(persC['sales'])
ax[0, 1] = plot_pacf(persC['sales'], ax=ax[0, 1])
ax[0, 2] = plot_acf(persC['sales'], ax=ax[0, 2])

ax[1, 0].set_title('Differencing Series')
ax[1, 0].plot(persC['sales'].diff().dropna())
ax[1, 1] = plot_pacf(persC['sales'].diff().dropna(), ax=ax[1, 1])
ax[1, 2] = plot_acf(persC['sales'].diff().dropna(), ax=ax[1, 2])

plt.show()

# %% [markdown]
# #Feature Engineering

# %%
# Imputasi missing value pada dcoilwtico
# Imputasi missing value dengan nilai sehari sebelumnya
persC['dcoilwtico'] = persC['dcoilwtico'].fillna(method='bfill')
persC
# Out:
# <ipython-input-23-28844d7389b8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   persC['dcoilwtico'] = persC['dcoilwtico'].fillna(method='bfill')
#                    family  sales  onpromotion  dcoilwtico
# date
# 2013-01-01  PERSONAL CARE      0            0          93
# 2013-01-02  PERSONAL CARE    427            0          93
# 2013-01-03  PERSONAL CARE    312            0          93
# 2013-01-04  PERSONAL CARE    265            0          93
# 2013-01-05  PERSONAL CARE    330            0          93
# ...                   ...    ...          ...         ...
# 2017-08-11  PERSONAL CARE    204            9          49
# 2017-08-12  PERSONAL CARE    159           12          48
# 2017-08-13  PERSONAL CARE    269           10          48
# 2017-08-14  PERSONAL CARE    196           10          48
# 2017-08-15  PERSONAL CARE    183            9          48
#
# [1684 rows x 4 columns]

# %%
#Mengambil value row kedua menjadi row pertama untuk menghilangkan outlier
persC.iloc[0, persC.columns.get_loc('sales')] = persC.iloc[1, persC.columns.get_loc('sales')]
persC
# Out:
#                    family  sales  onpromotion  dcoilwtico
# date
# 2013-01-01  PERSONAL CARE    427            0          93
# 2013-01-02  PERSONAL CARE    427            0          93
# 2013-01-03  PERSONAL CARE    312            0          93
# 2013-01-04  PERSONAL CARE    265            0          93
# 2013-01-05  PERSONAL CARE    330            0          93
# ...                   ...    ...          ...         ...
# 2017-08-11  PERSONAL CARE    204            9          49
# 2017-08-12  PERSONAL CARE    159           12          48
# 2017-08-13  PERSONAL CARE    269           10          48
# 2017-08-14  PERSONAL CARE    196           10          48
# 2017-08-15  PERSONAL CARE    183            9          48
#
# [1684 rows x 4 columns]

# %%
result = adfuller(persC['sales'].dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -4.245943
# p-value: 0.000550

# %%
persC.drop(['family'], axis=1, inplace=True)
persC
# Out:
# <ipython-input-26-675e2bad5305>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   persC.drop(['family'], axis=1, inplace=True)
#             sales  onpromotion  dcoilwtico
# date
# 2013-01-01    427            0          93
# 2013-01-02    427            0          93
# 2013-01-03    312            0          93
# 2013-01-04    265            0          93
# 2013-01-05    330            0          93
# ...           ...          ...         ...
# 2017-08-11    204            9          49
# 2017-08-12    159           12          48
# 2017-08-13    269           10          48
# 2017-08-14    196           10          48
# 2017-08-15    183            9          48
#
# [1684 rows x 3 columns]

# %%
# Membagi fitur tanggal menjadi tahun, bulan, dan hari
persC = persC.copy()
persC.loc[:, 'year'] = persC.index.year
persC.loc[:, 'month'] = persC.index.month
persC.loc[:, 'day'] = persC.index.day
persC.loc[:, 'dayofweek'] = persC.index.dayofweek
persC
# Out:
#             sales  onpromotion  dcoilwtico  year  month  day  dayofweek
# date
# 2013-01-01    427            0          93  2013      1    1          1
# 2013-01-02    427            0          93  2013      1    2          2
# 2013-01-03    312            0          93  2013      1    3          3
# 2013-01-04    265            0          93  2013      1    4          4
# 2013-01-05    330            0          93  2013      1    5          5
# ...           ...          ...         ...   ...    ...  ...        ...
# 2017-08-11    204            9          49  2017      8   11          4
# 2017-08-12    159           12          48  2017      8   12          5
# 2017-08-13    269           10          48  2017      8   13          6
# 2017-08-14    196           10          48  2017      8   14          0
# 2017-08-15    183            9          48  2017      8   15          1
#
# [1684 rows x 7 columns]

# %%
#Membuat lag feature
for i in range(1, 8):
    persC[f'lag_{i}'] = persC['sales'].shift(i)

persC.dropna(inplace=True)
persC.fillna(0, inplace=True)

persC
# Out:
#             sales  onpromotion  dcoilwtico  year  month  day  dayofweek  \
# date
# 2013-01-08    244            0          93  2013      1    8          1
# 2013-01-09    209            0          93  2013      1    9          2
# 2013-01-10    228            0          94  2013      1   10          3
# 2013-01-11    185            0          94  2013      1   11          4
# 2013-01-12    197            0          94  2013      1   12          5
# ...           ...          ...         ...   ...    ...  ...        ...
# 2017-08-11    204            9          49  2017      8   11          4
# 2017-08-12    159           12          48  2017      8   12          5
# 2017-08-13    269           10          48  2017      8   13          6
# 2017-08-14    196           10          48  2017      8   14          0
# 2017-08-15    183            9          48  2017      8   15          1
#
#             lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7
# date
# 2013-01-08    279    489    330    265    312    427    427
# 2013-01-09    244    279    489    330    265    312    427
# 2013-01-10    209    244    279    489    330    265    312
# 2013-01-11    228    209    244    279    489    330    265
# 2013-01-12    185    228    209    244    279    489    330
# ...           ...    ...    ...    ...    ...    ...    ...
# 2017-08-11    188    212    236    268    326    280    225
# 2017-08-12    204    188    212    236    268    326    280
# 2017-08-13    159    204    188    212    236    268    326
# 2017-08-14    269    159    204    188    212    236    268
# 2017-08-15    196    269    159    204    188    212    236
#
# [1677 rows x 14 columns]

# %%
#Melihat korelasi antara lag dengan target
lag_features = [f'lag_{i}' for i in range(1, 8)]
lag_correlation = persC[lag_features + ['sales']].corr()

plt.figure(figsize=(10, 6))
sns.heatmap(data=lag_correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap between Lag Features and Sales')
plt.xlabel('Features')
plt.ylabel('Lag Features')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##Granger Test untuk korelasi fitur

# %%
from statsmodels.tsa.stattools import grangercausalitytests

def granger_causation_matrix(data, variables, maxlag, test='ssr_chi2test'):
    """Computes Granger Causality matrix
    Returns: DataFrame

    test : str, {'ssr_chi2test', 'ssr_ftest', 'lrtest'}
        Type of Granger causality test
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for cause in df.columns:
        for effect in df.index:
            gc_result = grangercausalitytests(data[[cause, effect]], maxlag=maxlag, verbose=False)
            p_values = [round(gc_result[i+1][0][test][1],4) for i in range(maxlag)]
            min_p_value = np.min(p_values)
            df.loc[effect, cause] = min_p_value
    return df

# %%
import warnings
warnings.filterwarnings("ignore", message="verbose is deprecated")

#Melihat korelasi antar feature
variables = ['sales', 'onpromotion', 'dcoilwtico']
maxlag = 7

result = granger_causation_matrix(persC, variables, maxlag)

# Output Formatting
print("Granger Causality Results:\n")
result
# Out:
# Granger Causality Results:
#              sales  onpromotion  dcoilwtico
# sales            1            0           0
# onpromotion      0            1           0
# dcoilwtico       0            0           1

# %%
# Menambahkan rolling window mean pada sales sepanjang 7 hari
persC['sales_mean_7'] = persC['sales'].rolling(window=7).mean()
# Menambahkan rolling window mean pada sales sepanjang 30 hari
persC['sales_mean_30'] = persC['sales'].rolling(window=30).mean()

persC.dropna(inplace=True)
persC.fillna(0, inplace=True)

persC
# Out:
#             sales  onpromotion  dcoilwtico  year  month  day  dayofweek  \
# date
# 2013-02-06    211            0          96  2013      2    6          2
# 2013-02-07    185            0          96  2013      2    7          3
# 2013-02-08    201            0          96  2013      2    8          4
# 2013-02-09    224            0          97  2013      2    9          5
# 2013-02-10    149            0          97  2013      2   10          6
# ...           ...          ...         ...   ...    ...  ...        ...
# 2017-08-11    204            9          49  2017      8   11          4
# 2017-08-12    159           12          48  2017      8   12          5
# 2017-08-13    269           10          48  2017      8   13          6
# 2017-08-14    196           10          48  2017      8   14          0
# 2017-08-15    183            9          48  2017      8   15          1
#
#             lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  sales_mean_7  \
# date
# 2013-02-06    200    244    301    312    222    204    193           242
# 2013-02-07    211    200    244    301    312    222    204           239
# 2013-02-08    185    211    200    244    301    312    222           236
# 2013-02-09    201    185    211    200    244    301    312           224
# 2013-02-10    224    201    185    211    200    244    301           202
# ...           ...    ...    ...    ...    ...    ...    ...           ...
# 2017-08-11    188    212    236    268    326    280    225           245
# 2017-08-12    204    188    212    236    268    326    280           228
# 2017-08-13    159    204    188    212    236    268    326           219
# 2017-08-14    269    159    204    188    212    236    268           209
# 2017-08-15    196    269    159    204    188    212    236           202
#
#             sales_mean_30
# date
# 2013-02-06            223
# 2013-02-07            221
# 2013-02-08            221
# 2013-02-09            221
# 2013-02-10            220
# ...                   ...
# 2017-08-11            257
# 2017-08-12            257
# 2017-08-13            259
# 2017-08-14            255
# 2017-08-15            251
#
# [1648 rows x 16 columns]

# %%
#Melihat korelasi antara lag dengan target
mean = ['sales_mean_7', 'sales_mean_30']
sale_mean = persC[mean + ['sales']].corr()

plt.figure(figsize=(10, 6))
sns.heatmap(data=sale_mean, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap between Lag Features and Sales')
plt.xlabel('Features')
plt.ylabel('Lag Features')
plt.xticks(rotation=45)
plt.show()

# %%
#Delete feature tidak terpakai
persC.drop(columns=[f'lag_{i}' for i in range(1, 7)] + ['sales_mean_30'], axis=1, inplace=True)
persC
# Out:
#             sales  onpromotion  dcoilwtico  year  month  day  dayofweek  \
# date
# 2013-02-06    211            0          96  2013      2    6          2
# 2013-02-07    185            0          96  2013      2    7          3
# 2013-02-08    201            0          96  2013      2    8          4
# 2013-02-09    224            0          97  2013      2    9          5
# 2013-02-10    149            0          97  2013      2   10          6
# ...           ...          ...         ...   ...    ...  ...        ...
# 2017-08-11    204            9          49  2017      8   11          4
# 2017-08-12    159           12          48  2017      8   12          5
# 2017-08-13    269           10          48  2017      8   13          6
# 2017-08-14    196           10          48  2017      8   14          0
# 2017-08-15    183            9          48  2017      8   15          1
#
#             lag_7  sales_mean_7
# date
# 2013-02-06    193           242
# 2013-02-07    204           239
# 2013-02-08    222           236
# 2013-02-09    312           224
# 2013-02-10    301           202
# ...           ...           ...
# 2017-08-11    225           245
# 2017-08-12    280           228
# 2017-08-13    326           219
# 2017-08-14    268           209
# 2017-08-15    236           202
#
# [1648 rows x 9 columns]

# %%
# Split data menjadi data training dan data testing
train = persC[:-30]
test = persC[-30:]
print('Train shape:', train.shape)
print('Test shape:', test.shape)
# Out:
# Train shape: (1618, 9)
# Test shape: (30, 9)

# %% [markdown]
# #Modeling

# %% [markdown]
# ##Model SARIMAX

# %%
# Seasonal ARIMA X (SARIMAX)
model_sarimax = ARIMA(train['sales'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 7), exog=train[['onpromotion','sales_mean_7','lag_7']])
model_sarimax_fit = model_sarimax.fit()
print(model_sarimax_fit.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                     SARIMAX Results
# =======================================================================================
# Dep. Variable:                           sales   No. Observations:                 1618
# Model:             ARIMA(1, 1, 1)x(1, 1, 1, 7)   Log Likelihood               -8556.635
# Date:                         Fri, 15 Mar 2024   AIC                          17129.270
# Time:                                 09:41:15   BIC                          17172.342
# Sample:                                      0   HQIC                         17145.259
#                                         - 1618
# Covariance Type:                           opg
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# onpromotion      3.0082      0.526      5.715      0.000       1.977       4.040
# sales_mean_7     0.9766      0.046     21.286      0.000       0.887       1.067
# lag_7           -0.1229      0.035     -3.560      0.000      -0.191      -0.055
# ar.L1            0.3186      0.016     20.024      0.000       0.287       0.350
# ma.L1           -0.9989      0.007   -139.906      0.000      -1.013      -0.985
# ar.S.L7          0.1792      0.044      4.117      0.000       0.094       0.265
# ma.S.L7         -0.8480      0.016    -53.753      0.000      -0.879      -0.817
# sigma2        2393.9008     54.364     44.034      0.000    2287.349    2500.453
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.63   Jarque-Bera (JB):              1299.71
# Prob(Q):                              0.43   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.01   Skew:                             0.08
# Prob(H) (two-sided):                  0.90   Kurtosis:                         7.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Plot residual errors
residuals = pd.DataFrame(model_sarimax_fit.resid)
fig, ax = plt.subplots(1,2, figsize=(25,5))
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
# Prediction
exog_forecast = test[['onpromotion','sales_mean_7','lag_7']]  # Ambil nilai eksogen dari data uji
forecast = model_sarimax_fit.predict(start=len(train), end=len(train)+len(test)-1, exog=exog_forecast, typ='levels')
forecast.index = test.index

plt.figure(figsize=(15,5))
plt.title('Forecast vs Actual')
plt.plot(test['sales'], label='Test')
plt.plot(forecast, label='Forecast', color='r')
plt.legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %%
# check forecast row
forecastSARIMAX = pd.DataFrame({'test': test['sales'], 'forecast': forecast})
forecastSARIMAX
# Out:
#             test  forecast
# date
# 2017-07-17   282       253
# 2017-07-18   179       209
# 2017-07-19   328       232
# 2017-07-20   229       218
# 2017-07-21   206       229
# 2017-07-22   228       288
# 2017-07-23   343       320
# 2017-07-24   288       266
# 2017-07-25   295       254
# 2017-07-26   226       222
# 2017-07-27   189       208
# 2017-07-28   182       213
# 2017-07-29   335       311
# 2017-07-30   391       331
# 2017-07-31   236       278
# 2017-08-01   339       229
# 2017-08-02   292       264
# 2017-08-03   210       248
# 2017-08-04   225       266
# 2017-08-05   280       330
# 2017-08-06   326       345
# 2017-08-07   268       311
# 2017-08-08   236       239
# 2017-08-09   212       236
# 2017-08-10   188       213
# 2017-08-11   204       217
# 2017-08-12   159       281
# 2017-08-13   269       292
# 2017-08-14   196       234
# 2017-08-15   183       183

# %% [markdown]
# ##Model LSTM

# %%
# Split data
# Scalling

dcoilwtico_scaler = MinMaxScaler()
sales_scaler = MinMaxScaler()
x = persC[['lag_7', 'sales_mean_7', 'onpromotion']].copy()
y = persC['sales'].copy()

y = sales_scaler.fit_transform(y.values.reshape(-1, 1))
x['lag_7'] = sales_scaler.transform(x['lag_7'].values.reshape(-1, 1))
x['sales_mean_7'] = sales_scaler.transform(x['sales_mean_7'].values.reshape(-1, 1))
x['onpromotion'] = sales_scaler.transform(x['onpromotion'].values.reshape(-1, 1))

# %%
def load_data(X, seq_len, test_size=30):
    amount_of_features = X.shape[1]
    X_mat = X.values
    sequence_length = seq_len + 1
    data = []

    for index in range(len(X_mat) - sequence_length):
        data.append(X_mat[index: index + sequence_length])

    data = np.array(data)
    train_data = data[:-test_size]  # Exclude last 'test_size' data points for test set

    x_train = train_data[:, :-1]
    y_train = train_data[:, -1][:,-1]

    x_test = data[-test_size:, :-1]
    y_test = data[-test_size:, -1][:,-1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], amount_of_features))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], amount_of_features))

    return x_train, y_train, x_test, y_test

window = 7
x['sales'] = y
X_train, y_train, X_test, y_test = load_data(x, window,test_size=30)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1610, 7, 4) (1610,) (30, 7, 4) (30,)

# %%
#LSTM architecture
modelLSTM = Sequential()

# First LSTM layer with Dropout regularization
modelLSTM.add(LSTM(units=50, return_sequences=True, input_shape=(window, 4)))
modelLSTM.add(Dropout(0.2))
# Second LSTM layer
modelLSTM.add(LSTM(units=25, return_sequences=False))

modelLSTM.add(Dense(units=1, kernel_initializer='uniform', activation='linear'))

# Compiling the RNN
modelLSTM.compile(optimizer='adam',loss='mse')
# Fitting to the training set
start = time.time()
history1=modelLSTM.fit(X_train,y_train,epochs=100,batch_size=35, validation_split=0.05, verbose=1)
print ('compilation time : ', time.time() - start)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 9s 31ms/step - loss: 0.0733 - val_loss: 0.0079
# Epoch 2/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0140 - val_loss: 0.0097
# Epoch 3/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0134 - val_loss: 0.0074
# Epoch 4/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0130 - val_loss: 0.0077
# Epoch 5/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0129 - val_loss: 0.0082
# Epoch 6/100
# 44/44 [==============================] - 1s 11ms/step - loss: 0.0128 - val_loss: 0.0091
# Epoch 7/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0126 - val_loss: 0.0067
# Epoch 8/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0127 - val_loss: 0.0068
# Epoch 9/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0123 - val_loss: 0.0074
# Epoch 10/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0116 - val_loss: 0.0061
# Epoch 11/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0115 - val_loss: 0.0068
# Epoch 12/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0111 - val_loss: 0.0056
# Epoch 13/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0110 - val_loss: 0.0056
# Epoch 14/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0108 - val_loss: 0.0058
# Epoch 15/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0103 - val_loss: 0.0061
# Epoch 16/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0106 - val_loss: 0.0055
# Epoch 17/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0103 - val_loss: 0.0054
# Epoch 18/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0105 - val_loss: 0.0054
# Epoch 19/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0102 - val_loss: 0.0060
# Epoch 20/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0098 - val_loss: 0.0067
# Epoch 21/100
# 44/44 [==============================] - 1s 11ms/step - loss: 0.0099 - val_loss: 0.0052
# Epoch 22/100
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0102 - val_loss: 0.0051
# Epoch 23/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0098 - val_loss: 0.0058
# Epoch 24/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0099 - val_loss: 0.0058
# Epoch 25/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0099 - val_loss: 0.0061
# Epoch 26/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0097 - val_loss: 0.0052
# Epoch 27/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0094 - val_loss: 0.0049
# Epoch 28/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0092 - val_loss: 0.0049
# Epoch 29/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0095 - val_loss: 0.0057
# Epoch 30/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0090 - val_loss: 0.0049
# Epoch 31/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0088 - val_loss: 0.0047
# Epoch 32/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0089 - val_loss: 0.0047
# Epoch 33/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0090 - val_loss: 0.0052
# Epoch 34/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0088 - val_loss: 0.0046
# Epoch 35/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0088 - val_loss: 0.0047
# Epoch 36/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0084 - val_loss: 0.0048
# Epoch 37/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0085 - val_loss: 0.0045
# Epoch 38/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 39/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0083 - val_loss: 0.0044
# Epoch 40/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0083 - val_loss: 0.0044
# Epoch 41/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0084 - val_loss: 0.0043
# Epoch 42/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0083 - val_loss: 0.0049
# Epoch 43/100
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0083 - val_loss: 0.0043
# Epoch 44/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0080 - val_loss: 0.0045
# Epoch 45/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0081 - val_loss: 0.0044
# Epoch 46/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0084 - val_loss: 0.0046
# Epoch 47/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0080 - val_loss: 0.0041
# Epoch 48/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0079 - val_loss: 0.0042
# Epoch 49/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0082 - val_loss: 0.0043
# Epoch 50/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0081 - val_loss: 0.0044
# Epoch 51/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0082 - val_loss: 0.0041
# Epoch 52/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0080 - val_loss: 0.0040
# Epoch 53/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0079 - val_loss: 0.0041
# Epoch 54/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0077 - val_loss: 0.0041
# Epoch 55/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0079 - val_loss: 0.0053
# Epoch 56/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0079 - val_loss: 0.0041
# Epoch 57/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0039
# Epoch 58/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0044
# Epoch 59/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0043
# Epoch 60/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0078 - val_loss: 0.0040
# Epoch 61/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0076 - val_loss: 0.0039
# Epoch 62/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0077 - val_loss: 0.0042
# Epoch 63/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0076 - val_loss: 0.0040
# Epoch 64/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0077 - val_loss: 0.0039
# Epoch 65/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0077 - val_loss: 0.0040
# Epoch 66/100
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0076 - val_loss: 0.0038
# Epoch 67/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0041
# Epoch 68/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0037
# Epoch 69/100
# 44/44 [==============================] - 1s 11ms/step - loss: 0.0074 - val_loss: 0.0037
# Epoch 70/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0037
# Epoch 71/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0077 - val_loss: 0.0037
# Epoch 72/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0037
# Epoch 73/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0038
# Epoch 74/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0074 - val_loss: 0.0039
# Epoch 75/100
# 44/44 [==============================] - 1s 11ms/step - loss: 0.0076 - val_loss: 0.0041
# Epoch 76/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0076 - val_loss: 0.0044
# Epoch 77/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0076 - val_loss: 0.0040
# Epoch 78/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0077 - val_loss: 0.0038
# Epoch 79/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0075 - val_loss: 0.0038
# Epoch 80/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0076 - val_loss: 0.0040
# Epoch 81/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0076 - val_loss: 0.0036
# Epoch 82/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0073 - val_loss: 0.0041
# Epoch 83/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0075 - val_loss: 0.0036
# Epoch 84/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0075 - val_loss: 0.0043
# Epoch 85/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0075 - val_loss: 0.0036
# Epoch 86/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0036
# Epoch 87/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0074 - val_loss: 0.0038
# Epoch 88/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0074 - val_loss: 0.0037
# Epoch 89/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0074 - val_loss: 0.0038
# Epoch 90/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0072 - val_loss: 0.0040
# Epoch 91/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0071 - val_loss: 0.0037
# Epoch 92/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0075 - val_loss: 0.0043
# Epoch 93/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0072 - val_loss: 0.0038
# Epoch 94/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0074 - val_loss: 0.0036
# Epoch 95/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0074 - val_loss: 0.0039
# Epoch 96/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0074 - val_loss: 0.0036
# Epoch 97/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0075 - val_loss: 0.0036
# Epoch 98/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0073 - val_loss: 0.0035
# Epoch 99/100
# 44/44 [==============================] - 1s 11ms/step - loss: 0.0075 - val_loss: 0.0036
# Epoch 100/100
# 44/44 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 0.0036
# compilation time :  67.09006857872009

# %%
trainPredict = modelLSTM.predict(X_train)
testPredict = modelLSTM.predict(X_test)

trainPredict = sales_scaler.inverse_transform(trainPredict)
trainY = sales_scaler.inverse_transform([y_train])
testPredict = sales_scaler.inverse_transform(testPredict)
testY = sales_scaler.inverse_transform([y_test])

plot_predicted = testPredict.copy()
plot_predicted = plot_predicted.reshape(30, 1)
plot_actual = testY.copy()
plot_actual = plot_actual.reshape(30, 1)
print(plot_actual.shape)
print(plot_predicted.shape)
# Out:
# 51/51 [==============================] - 1s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# (30, 1)
# (30, 1)

# %%
plt.figure(figsize=(20,7))
plt.plot(pd.DataFrame(plot_predicted), label='Predicted')
plt.plot(pd.DataFrame(plot_actual), label='Actual')
plt.legend(loc='best')
plt.show()

# %%
plot_predicted = plot_predicted.reshape(30,)

forecastLSTM = pd.DataFrame({'test': test['sales'], 'forecast': plot_predicted}, index=test.index)
forecastLSTM
# Out:
#             test  forecast
# date
# 2017-07-17   282       313
# 2017-07-18   179       254
# 2017-07-19   328       232
# 2017-07-20   229       204
# 2017-07-21   206       233
# 2017-07-22   228       222
# 2017-07-23   343       290
# 2017-07-24   288       286
# 2017-07-25   295       259
# 2017-07-26   226       221
# 2017-07-27   189       254
# 2017-07-28   182       214
# 2017-07-29   335       199
# 2017-07-30   391       242
# 2017-07-31   236       342
# 2017-08-01   339       299
# 2017-08-02   292       231
# 2017-08-03   210       269
# 2017-08-04   225       240
# 2017-08-05   280       217
# 2017-08-06   326       290
# 2017-08-07   268       338
# 2017-08-08   236       264
# 2017-08-09   212       266
# 2017-08-10   188       223
# 2017-08-11   204       197
# 2017-08-12   159       199
# 2017-08-13   269       269
# 2017-08-14   196       267
# 2017-08-15   183       234

# %% [markdown]
# ##Facebook Prophet Model

# %%
trainP = train.copy()
trainP = trainP.reset_index()
trainP = trainP.rename(columns={'date': 'ds', 'sales': 'y'})

testP = test.copy()
testP = testP.reset_index()
testP = testP.rename(columns={'date': 'ds', 'sales': 'y'})

# %%
trainP.head()
# Out:
#           ds   y  onpromotion  dcoilwtico  year  month  day  dayofweek  lag_7  \
# 0 2013-02-06 211            0          96  2013      2    6          2    193
# 1 2013-02-07 185            0          96  2013      2    7          3    204
# 2 2013-02-08 201            0          96  2013      2    8          4    222
# 3 2013-02-09 224            0          97  2013      2    9          5    312
# 4 2013-02-10 149            0          97  2013      2   10          6    301
#
#    sales_mean_7
# 0           242
# 1           239
# 2           236
# 3           224
# 4           202

# %%
testP.head()
# Out:
#           ds   y  onpromotion  dcoilwtico  year  month  day  dayofweek  lag_7  \
# 0 2017-07-17 282            5          46  2017      7   17          0    249
# 1 2017-07-18 179            4          46  2017      7   18          1    160
# 2 2017-07-19 328            5          47  2017      7   19          2    197
# 3 2017-07-20 229            5          47  2017      7   20          3    174
# 4 2017-07-21 206            5          46  2017      7   21          4    189
#
#    sales_mean_7
# 0           233
# 1           236
# 2           255
# 3           263
# 4           265

# %%
model = Prophet()
model.fit(trainP)

future_dates = model.make_future_dataframe(periods=len(testP))
test_forecast = model.predict(future_dates)
future_dates
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptzq7a1ta/frj945zr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptzq7a1ta/a2amxj1l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80274', 'data', 'file=/tmp/tmptzq7a1ta/frj945zr.json', 'init=/tmp/tmptzq7a1ta/a2amxj1l.json', 'output', 'file=/tmp/tmptzq7a1ta/prophet_modelcot2x3pw/prophet_model-20240315094227.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:42:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:42:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#              ds
# 0    2013-02-06
# 1    2013-02-07
# 2    2013-02-08
# 3    2013-02-09
# 4    2013-02-10
# ...         ...
# 1643 2017-08-11
# 1644 2017-08-12
# 1645 2017-08-13
# 1646 2017-08-14
# 1647 2017-08-15
#
# [1648 rows x 1 columns]

# %%
# Combine actuals and forecasts for plotting
results = testP[['ds', 'y']].merge(test_forecast[['ds', 'yhat']], how='left', on='ds')
results.rename(columns={'y': 'test', 'yhat': 'forecast'}, inplace=True)

# Generate plot
plt.figure(figsize=(12, 6))
plt.plot(results['ds'], results['test'], label='test')
plt.plot(results['ds'], results['forecast'], label='forecast')
plt.legend()
plt.show()

# %%
results.set_index('ds')
# Out:
#             test  forecast
# ds
# 2017-07-17   282       252
# 2017-07-18   179       219
# 2017-07-19   328       222
# 2017-07-20   229       191
# 2017-07-21   206       205
# 2017-07-22   228       281
# 2017-07-23   343       333
# 2017-07-24   288       245
# 2017-07-25   295       211
# 2017-07-26   226       214
# 2017-07-27   189       182
# 2017-07-28   182       196
# 2017-07-29   335       272
# 2017-07-30   391       325
# 2017-07-31   236       236
# 2017-08-01   339       203
# 2017-08-02   292       206
# 2017-08-03   210       175
# 2017-08-04   225       189
# 2017-08-05   280       266
# 2017-08-06   326       319
# 2017-08-07   268       232
# 2017-08-08   236       200
# 2017-08-09   212       204
# 2017-08-10   188       174
# 2017-08-11   204       189
# 2017-08-12   159       268
# 2017-08-13   269       322
# 2017-08-14   196       235
# 2017-08-15   183       204

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

#MAPE
def mapeEv(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

model = [forecastSARIMAX, forecastLSTM, results]
model_name = ['SARIMAX', 'LSTM', 'FBProphet']
metrics = []

for i in range(len(model)):
    mae = mean_absolute_error(model[i]['test'], model[i]['forecast'])
    mse = mean_squared_error(model[i]['test'], model[i]['forecast'])
    rmse = np.sqrt(mse)
    mape = mapeEv(model[i]['test'], model[i]['forecast'])
    metrics.append([mae, mse, rmse, mape])

metrics = pd.DataFrame(metrics, columns=['MAE', 'MSE', 'RMSE', 'MAPE'], index=model_name)
metrics
# Out:
#            MAE   MSE  RMSE  MAPE
# SARIMAX     36 2,137    46    15
# LSTM        49 3,737    61    20
# FBProphet   40 2,803    53    16
