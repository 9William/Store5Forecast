# %% [markdown]
# #Library

# %%
#Pip Install
#!pip install --upgrade statsmodels
#!pip install prophet

# %%
# Import library yang akan digunakan
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time

from prophet import Prophet
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# Import min-max scaling function
from sklearn.preprocessing import MinMaxScaler


# Import keras lstm model
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Bidirectional, GRU, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from keras.preprocessing.sequence import TimeseriesGenerator

# Metrics
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# #Pre Processing Data

# %%
df_train = pd.read_csv('store5.csv')
df_train
# Out:
#             id        date  store_nbr                      family  sales  \
# 0         1452  2013-01-01          5                  AUTOMOTIVE      0
# 1         1453  2013-01-01          5                   BABY CARE      0
# 2         1454  2013-01-01          5                      BEAUTY      0
# 3         1455  2013-01-01          5                   BEVERAGES      0
# 4         1456  2013-01-01          5                       BOOKS      0
# ...        ...         ...        ...                         ...    ...
# 55567  3000586  2017-08-15          5                     POULTRY    241
# 55568  3000587  2017-08-15          5              PREPARED FOODS     52
# 55569  3000588  2017-08-15          5                     PRODUCE  1,358
# 55570  3000589  2017-08-15          5  SCHOOL AND OFFICE SUPPLIES      0
# 55571  3000590  2017-08-15          5                     SEAFOOD     10
#
#        onpromotion  dcoilwtico
# 0                0         NaN
# 1                0         NaN
# 2                0         NaN
# 3                0         NaN
# 4                0         NaN
# ...            ...         ...
# 55567            1          48
# 55568            0          48
# 55569            4          48
# 55570            0          48
# 55571            0          48
#
# [55572 rows x 7 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55572 entries, 0 to 55571
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           55572 non-null  int64
#  1   date         55572 non-null  object
#  2   store_nbr    55572 non-null  int64
#  3   family       55572 non-null  object
#  4   sales        55572 non-null  float64
#  5   onpromotion  55572 non-null  int64
#  6   dcoilwtico   38379 non-null  float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 3.0+ MB

# %%
# Check for missing values
df_train.isnull().sum()
# Out:
# id                 0
# date               0
# store_nbr          0
# family             0
# sales              0
# onpromotion        0
# dcoilwtico     17193
# dtype: int64

# %%
# hapus kolom id dan store_nbr
df_train.drop(['id', 'store_nbr'], axis=1, inplace=True)
# Mengubah tipe data kolom date menjadi datetime
df_train['date'] = pd.to_datetime(df_train['date'])
# Mengurutkan data berdasarkan tanggal
df_train = df_train.set_index('date')
df_train
# Out:
#                                 family  sales  onpromotion  dcoilwtico
# date
# 2013-01-01                  AUTOMOTIVE      0            0         NaN
# 2013-01-01                   BABY CARE      0            0         NaN
# 2013-01-01                      BEAUTY      0            0         NaN
# 2013-01-01                   BEVERAGES      0            0         NaN
# 2013-01-01                       BOOKS      0            0         NaN
# ...                                ...    ...          ...         ...
# 2017-08-15                     POULTRY    241            1          48
# 2017-08-15              PREPARED FOODS     52            0          48
# 2017-08-15                     PRODUCE  1,358            4          48
# 2017-08-15  SCHOOL AND OFFICE SUPPLIES      0            0          48
# 2017-08-15                     SEAFOOD     10            0          48
#
# [55572 rows x 4 columns]

# %%
# Check  value
df_train['family'].value_counts()
# Out:
# AUTOMOTIVE                    1684
# HOME APPLIANCES               1684
# SCHOOL AND OFFICE SUPPLIES    1684
# PRODUCE                       1684
# PREPARED FOODS                1684
# POULTRY                       1684
# PLAYERS AND ELECTRONICS       1684
# PET SUPPLIES                  1684
# PERSONAL CARE                 1684
# MEATS                         1684
# MAGAZINES                     1684
# LIQUOR,WINE,BEER              1684
# LINGERIE                      1684
# LAWN AND GARDEN               1684
# LADIESWEAR                    1684
# HOME CARE                     1684
# HOME AND KITCHEN II           1684
# BABY CARE                     1684
# HOME AND KITCHEN I            1684
# HARDWARE                      1684
# GROCERY II                    1684
# GROCERY I                     1684
# FROZEN FOODS                  1684
# EGGS                          1684
# DELI                          1684
# DAIRY                         1684
# CLEANING                      1684
# CELEBRATION                   1684
# BREAD/BAKERY                  1684
# BOOKS                         1684
# BEVERAGES                     1684
# BEAUTY                        1684
# SEAFOOD                       1684
# Name: family, dtype: int64

# %%
# Total penjualan per family dengan format yang mudah dilihat
pd.options.display.float_format = '{:,.0f}'.format

df_train.groupby('family')['sales'].sum().sort_values(ascending=False)
# Out:
# family
# GROCERY I                    5,262,682
# BEVERAGES                    2,533,831
# CLEANING                     1,667,748
# PRODUCE                      1,653,582
# DAIRY                          871,283
# BREAD/BAKERY                   642,855
# MEATS                          477,104
# PERSONAL CARE                  450,166
# POULTRY                        419,630
# DELI                           415,271
# FROZEN FOODS                   269,669
# HOME CARE                      239,283
# EGGS                           190,851
# PREPARED FOODS                 147,991
# LIQUOR,WINE,BEER               110,414
# HOME AND KITCHEN II             37,238
# GROCERY II                      33,241
# LINGERIE                        31,561
# HOME AND KITCHEN I              30,107
# CELEBRATION                     26,176
# SEAFOOD                         22,359
# LADIESWEAR                      14,813
# AUTOMOTIVE                       9,194
# BEAUTY                           8,684
# PLAYERS AND ELECTRONICS          8,024
# MAGAZINES                        6,569
# LAWN AND GARDEN                  4,970
# PET SUPPLIES                     3,199
# HARDWARE                         1,725
# HOME APPLIANCES                    926
# SCHOOL AND OFFICE SUPPLIES         813
# BOOKS                              230
# BABY CARE                          215
# Name: sales, dtype: float64

# %%
# Total penjualan per family dengan format yang mudah dilihat
pd.options.display.float_format = '{:,.0f}'.format

df_train.groupby('family')['onpromotion'].sum().sort_values(ascending=False)
# Out:
# family
# GROCERY I                     37323
# PRODUCE                       24483
# BEVERAGES                     18413
# CLEANING                      12786
# DELI                          12448
# DAIRY                         10580
# MEATS                          6669
# PERSONAL CARE                  4547
# EGGS                           4440
# POULTRY                        4199
# BREAD/BAKERY                   3347
# HOME CARE                      3335
# FROZEN FOODS                   1953
# LIQUOR,WINE,BEER               1041
# HOME AND KITCHEN I              924
# SEAFOOD                         881
# HOME AND KITCHEN II             690
# PREPARED FOODS                  416
# BEAUTY                          261
# CELEBRATION                     206
# LAWN AND GARDEN                 157
# SCHOOL AND OFFICE SUPPLIES       77
# GROCERY II                       60
# LINGERIE                         57
# PET SUPPLIES                     42
# AUTOMOTIVE                       19
# PLAYERS AND ELECTRONICS           9
# LADIESWEAR                        3
# BABY CARE                         2
# HARDWARE                          1
# MAGAZINES                         1
# HOME APPLIANCES                   0
# BOOKS                             0
# Name: onpromotion, dtype: int64

# %% [markdown]
# #Visualisasi data

# %%
# Ambil data penjualan untuk family poultry
poultry = df_train['family']=='POULTRY'
poultry = df_train[poultry]
poultry
# Out:
#              family  sales  onpromotion  dcoilwtico
# date
# 2013-01-01  POULTRY      0            0         NaN
# 2013-01-02  POULTRY    312            0          93
# 2013-01-03  POULTRY    196            0          93
# 2013-01-04  POULTRY    167            0          93
# 2013-01-05  POULTRY    226            0         NaN
# ...             ...    ...          ...         ...
# 2017-08-11  POULTRY    298           24          49
# 2017-08-12  POULTRY    214            0         NaN
# 2017-08-13  POULTRY    233            0         NaN
# 2017-08-14  POULTRY    203            0          48
# 2017-08-15  POULTRY    241            1          48
#
# [1684 rows x 4 columns]

# %%
plt.figure(figsize=(20,6))
sns.set(style='whitegrid')

sns.lineplot(data=poultry, x='date', y='onpromotion', label='onpromotion')
plt.title('Pergerakan Promotion')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.set(style='whitegrid')

sns.lineplot(data=poultry, x='date', y='dcoilwtico', label='dcoilwtico')
plt.title('Pergerakan Minyak')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# Melihat pergerakan penjualan, onpromotion dan minyak pada family poultry
plt.figure(figsize=(20,6))
sns.set(style='whitegrid')
sns.lineplot(data=poultry, x='date', y='sales', label='sales')
sns.lineplot(data=poultry, x='date', y='onpromotion', label='onpromotion')
sns.lineplot(data=poultry, x='date', y='dcoilwtico', label='dcoilwtico')
plt.title('Penjualan dan Onpromotion pada Family poultry')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
#Mengubah index data menjadi tanggal 2016 2017
#poultry = poultry['2016':'2017']

# %%
# Melihat kembali penjualan dan onpromotion pada family poultry
plt.figure(figsize=(20,6))
sns.set(style='whitegrid')
sns.lineplot(data=poultry, x='date', y='sales', label='sales')
sns.lineplot(data=poultry, x='date', y='onpromotion', label='onpromotion')
sns.lineplot(data=poultry, x='date', y='dcoilwtico', label='dcoilwtico')
plt.title('Penjualan dan Onpromotion pada Family poultry')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
corr_matrix = df_train.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap Correlation')
plt.show()
# Out:
# <ipython-input-65-99c40dc92ed5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df_train.corr()

# %%
# Decompose data transactions
plot_decompose = seasonal_decompose(poultry['sales'], model='additive', period=30)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(20, 10))
plot_decompose.observed.plot(ax=ax1)
plot_decompose.trend.plot(ax=ax2)
plot_decompose.seasonal.plot(ax=ax3)
plot_decompose.resid.plot(ax=ax4)
# Out:
# <Axes: xlabel='date'>

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log
result = adfuller(poultry['sales'].dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -3.032760
# p-value: 0.031946

# %%
# Plot ACF dan PACF
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
fig, ax = plt.subplots(2, 3, figsize=(25, 10))

ax[0, 0].set_title('Original Series')
ax[0, 0].plot(poultry['sales'])
ax[0, 1] = plot_pacf(poultry['sales'], ax=ax[0, 1])
ax[0, 2] = plot_acf(poultry['sales'], ax=ax[0, 2])

ax[1, 0].set_title('Differencing Series')
ax[1, 0].plot(poultry['sales'].diff().dropna())
ax[1, 1] = plot_pacf(poultry['sales'].diff().dropna(), ax=ax[1, 1])
ax[1, 2] = plot_acf(poultry['sales'].diff().dropna(), ax=ax[1, 2])

plt.show()

# %% [markdown]
# #Feature Engineering

# %%
# Imputasi missing value pada dcoilwtico
# Imputasi missing value dengan nilai sehari sebelumnya
poultry['dcoilwtico'] = poultry['dcoilwtico'].fillna(method='bfill')
poultry
# Out:
# <ipython-input-69-1ecaff7ee79a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poultry['dcoilwtico'] = poultry['dcoilwtico'].fillna(method='bfill')
#              family  sales  onpromotion  dcoilwtico
# date
# 2013-01-01  POULTRY      0            0          93
# 2013-01-02  POULTRY    312            0          93
# 2013-01-03  POULTRY    196            0          93
# 2013-01-04  POULTRY    167            0          93
# 2013-01-05  POULTRY    226            0          93
# ...             ...    ...          ...         ...
# 2017-08-11  POULTRY    298           24          49
# 2017-08-12  POULTRY    214            0          48
# 2017-08-13  POULTRY    233            0          48
# 2017-08-14  POULTRY    203            0          48
# 2017-08-15  POULTRY    241            1          48
#
# [1684 rows x 4 columns]

# %%
#Mengambil value row kedua menjadi row pertama untuk menghilangkan outlier
poultry.iloc[0, poultry.columns.get_loc('sales')] = poultry.iloc[1, poultry.columns.get_loc('sales')]
poultry
# Out:
#              family  sales  onpromotion  dcoilwtico
# date
# 2013-01-01  POULTRY    312            0          93
# 2013-01-02  POULTRY    312            0          93
# 2013-01-03  POULTRY    196            0          93
# 2013-01-04  POULTRY    167            0          93
# 2013-01-05  POULTRY    226            0          93
# ...             ...    ...          ...         ...
# 2017-08-11  POULTRY    298           24          49
# 2017-08-12  POULTRY    214            0          48
# 2017-08-13  POULTRY    233            0          48
# 2017-08-14  POULTRY    203            0          48
# 2017-08-15  POULTRY    241            1          48
#
# [1684 rows x 4 columns]

# %%
result = adfuller(poultry['sales'].dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -3.015454
# p-value: 0.033476

# %%
poultry.drop(['family'], axis=1, inplace=True)
poultry
# Out:
# <ipython-input-72-a33efd0f678d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poultry.drop(['family'], axis=1, inplace=True)
#             sales  onpromotion  dcoilwtico
# date
# 2013-01-01    312            0          93
# 2013-01-02    312            0          93
# 2013-01-03    196            0          93
# 2013-01-04    167            0          93
# 2013-01-05    226            0          93
# ...           ...          ...         ...
# 2017-08-11    298           24          49
# 2017-08-12    214            0          48
# 2017-08-13    233            0          48
# 2017-08-14    203            0          48
# 2017-08-15    241            1          48
#
# [1684 rows x 3 columns]

# %%
# Membagi fitur tanggal menjadi tahun, bulan, dan hari
poultry = poultry.copy()
poultry.loc[:, 'year'] = poultry.index.year
poultry.loc[:, 'month'] = poultry.index.month
poultry.loc[:, 'day'] = poultry.index.day
poultry.loc[:, 'dayofweek'] = poultry.index.dayofweek
poultry
# Out:
#             sales  onpromotion  dcoilwtico  year  month  day  dayofweek
# date
# 2013-01-01    312            0          93  2013      1    1          1
# 2013-01-02    312            0          93  2013      1    2          2
# 2013-01-03    196            0          93  2013      1    3          3
# 2013-01-04    167            0          93  2013      1    4          4
# 2013-01-05    226            0          93  2013      1    5          5
# ...           ...          ...         ...   ...    ...  ...        ...
# 2017-08-11    298           24          49  2017      8   11          4
# 2017-08-12    214            0          48  2017      8   12          5
# 2017-08-13    233            0          48  2017      8   13          6
# 2017-08-14    203            0          48  2017      8   14          0
# 2017-08-15    241            1          48  2017      8   15          1
#
# [1684 rows x 7 columns]

# %%
#Membuat lag feature
for i in range(1, 8):
    poultry[f'lag_{i}'] = poultry['sales'].shift(i)

poultry.dropna(inplace=True)
poultry.fillna(0, inplace=True)

poultry
# Out:
#             sales  onpromotion  dcoilwtico  year  month  day  dayofweek  \
# date
# 2013-01-08    161            0          93  2013      1    8          1
# 2013-01-09    159            0          93  2013      1    9          2
# 2013-01-10    148            0          94  2013      1   10          3
# 2013-01-11    150            0          94  2013      1   11          4
# 2013-01-12    169            0          94  2013      1   12          5
# ...           ...          ...         ...   ...    ...  ...        ...
# 2017-08-11    298           24          49  2017      8   11          4
# 2017-08-12    214            0          48  2017      8   12          5
# 2017-08-13    233            0          48  2017      8   13          6
# 2017-08-14    203            0          48  2017      8   14          0
# 2017-08-15    241            1          48  2017      8   15          1
#
#             lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7
# date
# 2013-01-08    157    268    226    167    196    312    312
# 2013-01-09    161    157    268    226    167    196    312
# 2013-01-10    159    161    157    268    226    167    196
# 2013-01-11    148    159    161    157    268    226    167
# 2013-01-12    150    148    159    161    157    268    226
# ...           ...    ...    ...    ...    ...    ...    ...
# 2017-08-11    199    216    214    176    253    278    303
# 2017-08-12    298    199    216    214    176    253    278
# 2017-08-13    214    298    199    216    214    176    253
# 2017-08-14    233    214    298    199    216    214    176
# 2017-08-15    203    233    214    298    199    216    214
#
# [1677 rows x 14 columns]

# %%
#Melihat korelasi antara lag dengan target
lag_features = [f'lag_{i}' for i in range(1, 8)]
lag_correlation = poultry[lag_features + ['sales']].corr()

plt.figure(figsize=(10, 6))
sns.heatmap(data=lag_correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap between Lag Features and Sales')
plt.xlabel('Features')
plt.ylabel('Lag Features')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##Granger Test untuk korelasi fitur

# %%
from statsmodels.tsa.stattools import grangercausalitytests

def granger_causation_matrix(data, variables, maxlag, test='ssr_chi2test'):
    """Computes Granger Causality matrix
    Returns: DataFrame

    test : str, {'ssr_chi2test', 'ssr_ftest', 'lrtest'}
        Type of Granger causality test
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for cause in df.columns:
        for effect in df.index:
            gc_result = grangercausalitytests(data[[cause, effect]], maxlag=maxlag, verbose=False)
            p_values = [round(gc_result[i+1][0][test][1],4) for i in range(maxlag)]
            min_p_value = np.min(p_values)
            df.loc[effect, cause] = min_p_value
    return df

# %%
import warnings
warnings.filterwarnings("ignore", message="verbose is deprecated")

#Melihat korelasi antar feature
variables = ['sales', 'onpromotion', 'dcoilwtico']
maxlag = 7

result = granger_causation_matrix(poultry, variables, maxlag)

# Output Formatting
print("Granger Causality Results:\n")
result
# Out:
# Granger Causality Results:
#              sales  onpromotion  dcoilwtico
# sales            1            0           0
# onpromotion      0            1           0
# dcoilwtico       0            0           1

# %%
# Menambahkan rolling window mean pada sales sepanjang 7 hari
poultry['sales_mean_7'] = poultry['sales'].rolling(window=7).mean()
# Menambahkan rolling window mean pada sales sepanjang 30 hari
poultry['sales_mean_30'] = poultry['sales'].rolling(window=30).mean()

poultry.dropna(inplace=True)
poultry.fillna(0, inplace=True)

poultry
# Out:
#             sales  onpromotion  dcoilwtico  year  month  day  dayofweek  \
# date
# 2013-02-06    179            0          96  2013      2    6          2
# 2013-02-07    150            0          96  2013      2    7          3
# 2013-02-08    189            0          96  2013      2    8          4
# 2013-02-09    202            0          97  2013      2    9          5
# 2013-02-10    191            0          97  2013      2   10          6
# ...           ...          ...         ...   ...    ...  ...        ...
# 2017-08-11    298           24          49  2017      8   11          4
# 2017-08-12    214            0          48  2017      8   12          5
# 2017-08-13    233            0          48  2017      8   13          6
# 2017-08-14    203            0          48  2017      8   14          0
# 2017-08-15    241            1          48  2017      8   15          1
#
#             lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  sales_mean_7  \
# date
# 2013-02-06    181    181    242    258    186    170    129           199
# 2013-02-07    179    181    181    242    258    186    170           197
# 2013-02-08    150    179    181    181    242    258    186           197
# 2013-02-09    189    150    179    181    181    242    258           189
# 2013-02-10    202    189    150    179    181    181    242           182
# ...           ...    ...    ...    ...    ...    ...    ...           ...
# 2017-08-11    199    216    214    176    253    278    303           233
# 2017-08-12    298    199    216    214    176    253    278           224
# 2017-08-13    214    298    199    216    214    176    253           221
# 2017-08-14    233    214    298    199    216    214    176           225
# 2017-08-15    203    233    214    298    199    216    214           229
#
#             sales_mean_30
# date
# 2013-02-06            177
# 2013-02-07            177
# 2013-02-08            178
# 2013-02-09            179
# 2013-02-10            181
# ...                   ...
# 2017-08-11            240
# 2017-08-12            241
# 2017-08-13            237
# 2017-08-14            237
# 2017-08-15            235
#
# [1648 rows x 16 columns]

# %%
#Melihat korelasi antara lag dengan target
mean = ['sales_mean_7', 'sales_mean_30']
sale_mean = poultry[mean + ['sales']].corr()

plt.figure(figsize=(10, 6))
sns.heatmap(data=sale_mean, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap between Lag Features and Sales')
plt.xlabel('Features')
plt.ylabel('Lag Features')
plt.xticks(rotation=45)
plt.show()

# %%
#Delete feature tidak terpakai
poultry.drop(columns=[f'lag_{i}' for i in range(1, 7)] + ['sales_mean_30'], axis=1, inplace=True)
poultry
# Out:
#             sales  onpromotion  dcoilwtico  year  month  day  dayofweek  \
# date
# 2013-02-06    179            0          96  2013      2    6          2
# 2013-02-07    150            0          96  2013      2    7          3
# 2013-02-08    189            0          96  2013      2    8          4
# 2013-02-09    202            0          97  2013      2    9          5
# 2013-02-10    191            0          97  2013      2   10          6
# ...           ...          ...         ...   ...    ...  ...        ...
# 2017-08-11    298           24          49  2017      8   11          4
# 2017-08-12    214            0          48  2017      8   12          5
# 2017-08-13    233            0          48  2017      8   13          6
# 2017-08-14    203            0          48  2017      8   14          0
# 2017-08-15    241            1          48  2017      8   15          1
#
#             lag_7  sales_mean_7
# date
# 2013-02-06    129           199
# 2013-02-07    170           197
# 2013-02-08    186           197
# 2013-02-09    258           189
# 2013-02-10    242           182
# ...           ...           ...
# 2017-08-11    303           233
# 2017-08-12    278           224
# 2017-08-13    253           221
# 2017-08-14    176           225
# 2017-08-15    214           229
#
# [1648 rows x 9 columns]

# %%
# Split data menjadi data training dan data testing
train = poultry[:-30]
test = poultry[-30:]
print('Train shape:', train.shape)
print('Test shape:', test.shape)
# Out:
# Train shape: (1618, 9)
# Test shape: (30, 9)

# %% [markdown]
# #Modeling

# %% [markdown]
# ##Model SARIMAX

# %%
# Seasonal ARIMA X (SARIMAX)
model_sarimax = ARIMA(train['sales'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 7), exog=train[['onpromotion','sales_mean_7','lag_7']])
model_sarimax_fit = model_sarimax.fit()
print(model_sarimax_fit.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                     SARIMAX Results
# =======================================================================================
# Dep. Variable:                           sales   No. Observations:                 1618
# Model:             ARIMA(1, 1, 1)x(1, 1, 1, 7)   Log Likelihood               -8404.778
# Date:                         Fri, 15 Mar 2024   AIC                          16825.557
# Time:                                 09:54:05   BIC                          16868.629
# Sample:                                      0   HQIC                         16841.546
#                                         - 1618
# Covariance Type:                           opg
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# onpromotion      3.9235      0.256     15.309      0.000       3.421       4.426
# sales_mean_7     1.0647      0.021     49.537      0.000       1.023       1.107
# lag_7           -0.1832      0.018    -10.367      0.000      -0.218      -0.149
# ar.L1            0.1251      0.014      9.154      0.000       0.098       0.152
# ma.L1           -0.9996      0.022    -45.302      0.000      -1.043      -0.956
# ar.S.L7          0.1781      0.031      5.728      0.000       0.117       0.239
# ma.S.L7         -0.8747      0.015    -59.833      0.000      -0.903      -0.846
# sigma2        1981.0478     54.948     36.053      0.000    1873.351    2088.745
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):              5553.42
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.58   Skew:                            -0.18
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Plot residual errors
residuals = pd.DataFrame(model_sarimax_fit.resid)
fig, ax = plt.subplots(1,2, figsize=(25,5))
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
# Prediction
exog_forecast = test[['onpromotion','sales_mean_7','lag_7']]  # Ambil nilai eksogen dari data uji
forecast = model_sarimax_fit.predict(start=len(train), end=len(train)+len(test)-1, exog=exog_forecast, typ='levels')
forecast.index = test.index

plt.figure(figsize=(15,5))
plt.title('Forecast vs Actual')
plt.plot(test['sales'], label='Test')
plt.plot(forecast, label='Forecast', color='r')
plt.legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %%
# check forecast row
forecastSARIMAX = pd.DataFrame({'test': test['sales'], 'forecast': forecast})
forecastSARIMAX
# Out:
#             test  forecast
# date
# 2017-07-17   258       224
# 2017-07-18   179       224
# 2017-07-19   256       216
# 2017-07-20   155       189
# 2017-07-21   332       313
# 2017-07-22   231       250
# 2017-07-23   323       283
# 2017-07-24   215       219
# 2017-07-25   231       243
# 2017-07-26   264       210
# 2017-07-27   125       196
# 2017-07-28   284       304
# 2017-07-29   259       256
# 2017-07-30   261       256
# 2017-07-31   210       219
# 2017-08-01   216       215
# 2017-08-02   225       183
# 2017-08-03   209       193
# 2017-08-04   303       326
# 2017-08-05   278       251
# 2017-08-06   253       275
# 2017-08-07   176       228
# 2017-08-08   214       224
# 2017-08-09   216       200
# 2017-08-10   199       174
# 2017-08-11   298       299
# 2017-08-12   214       228
# 2017-08-13   233       254
# 2017-08-14   203       218
# 2017-08-15   241       220

# %% [markdown]
# ##Model LSTM

# %%
# Split data
# Scalling

dcoilwtico_scaler = MinMaxScaler()
sales_scaler = MinMaxScaler()
x = poultry[['lag_7', 'sales_mean_7', 'onpromotion']].copy()
y = poultry['sales'].copy()

y = sales_scaler.fit_transform(y.values.reshape(-1, 1))
x['lag_7'] = sales_scaler.transform(x['lag_7'].values.reshape(-1, 1))
x['sales_mean_7'] = sales_scaler.transform(x['sales_mean_7'].values.reshape(-1, 1))
x['onpromotion'] = sales_scaler.transform(x['onpromotion'].values.reshape(-1, 1))

# %%
def load_data(X, seq_len, test_size=30):
    amount_of_features = X.shape[1]
    X_mat = X.values
    sequence_length = seq_len + 1
    data = []

    for index in range(len(X_mat) - sequence_length):
        data.append(X_mat[index: index + sequence_length])

    data = np.array(data)
    train_data = data[:-test_size]  # Exclude last 'test_size' data points for test set

    x_train = train_data[:, :-1]
    y_train = train_data[:, -1][:,-1]

    x_test = data[-test_size:, :-1]
    y_test = data[-test_size:, -1][:,-1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], amount_of_features))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], amount_of_features))

    return x_train, y_train, x_test, y_test

window = 7
x['sales'] = y
X_train, y_train, X_test, y_test = load_data(x, window,test_size=30)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1610, 7, 4) (1610,) (30, 7, 4) (30,)

# %%
#LSTM architecture
modelLSTM = Sequential()

# First LSTM layer with Dropout regularization
modelLSTM.add(LSTM(units=50, return_sequences=True, input_shape=(window, 4)))
modelLSTM.add(Dropout(0.2))
# Second LSTM layer
modelLSTM.add(LSTM(units=25, return_sequences=False))

modelLSTM.add(Dense(units=1, kernel_initializer='uniform', activation='linear'))

# Compiling the RNN
modelLSTM.compile(optimizer='adam',loss='mse')
# Fitting to the training set
start = time.time()
history1=modelLSTM.fit(X_train,y_train,epochs=100,batch_size=35, validation_split=0.05, verbose=1)
print ('compilation time : ', time.time() - start)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 14s 117ms/step - loss: 0.0711 - val_loss: 0.0064
# Epoch 2/100
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0099 - val_loss: 0.0060
# Epoch 3/100
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0094 - val_loss: 0.0065
# Epoch 4/100
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0089 - val_loss: 0.0060
# Epoch 5/100
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0086 - val_loss: 0.0063
# Epoch 6/100
# 44/44 [==============================] - 1s 27ms/step - loss: 0.0085 - val_loss: 0.0058
# Epoch 7/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0083 - val_loss: 0.0059
# Epoch 8/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0083 - val_loss: 0.0058
# Epoch 9/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0082 - val_loss: 0.0056
# Epoch 10/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0084 - val_loss: 0.0056
# Epoch 11/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0081 - val_loss: 0.0061
# Epoch 12/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0079 - val_loss: 0.0057
# Epoch 13/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0079 - val_loss: 0.0053
# Epoch 14/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0075 - val_loss: 0.0053
# Epoch 15/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0076 - val_loss: 0.0050
# Epoch 16/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0075 - val_loss: 0.0051
# Epoch 17/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0075 - val_loss: 0.0051
# Epoch 18/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0074 - val_loss: 0.0049
# Epoch 19/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0075 - val_loss: 0.0049
# Epoch 20/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0071 - val_loss: 0.0049
# Epoch 21/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0072 - val_loss: 0.0051
# Epoch 22/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0075 - val_loss: 0.0054
# Epoch 23/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0072 - val_loss: 0.0049
# Epoch 24/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0071 - val_loss: 0.0050
# Epoch 25/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0071 - val_loss: 0.0062
# Epoch 26/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0071 - val_loss: 0.0056
# Epoch 27/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0070 - val_loss: 0.0049
# Epoch 28/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0070 - val_loss: 0.0047
# Epoch 29/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0069 - val_loss: 0.0046
# Epoch 30/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0068 - val_loss: 0.0050
# Epoch 31/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0068 - val_loss: 0.0047
# Epoch 32/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0067 - val_loss: 0.0047
# Epoch 33/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0068 - val_loss: 0.0047
# Epoch 34/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0068 - val_loss: 0.0046
# Epoch 35/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0069 - val_loss: 0.0048
# Epoch 36/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0067 - val_loss: 0.0048
# Epoch 37/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0067 - val_loss: 0.0046
# Epoch 38/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0068 - val_loss: 0.0046
# Epoch 39/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0068 - val_loss: 0.0045
# Epoch 40/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 41/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0066 - val_loss: 0.0052
# Epoch 42/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0067 - val_loss: 0.0046
# Epoch 43/100
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0068 - val_loss: 0.0045
# Epoch 44/100
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 45/100
# 44/44 [==============================] - 1s 28ms/step - loss: 0.0065 - val_loss: 0.0045
# Epoch 46/100
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0065 - val_loss: 0.0049
# Epoch 47/100
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0065 - val_loss: 0.0044
# Epoch 48/100
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0064 - val_loss: 0.0046
# Epoch 49/100
# 44/44 [==============================] - 1s 33ms/step - loss: 0.0066 - val_loss: 0.0045
# Epoch 50/100
# 44/44 [==============================] - 1s 30ms/step - loss: 0.0065 - val_loss: 0.0045
# Epoch 51/100
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0065 - val_loss: 0.0048
# Epoch 52/100
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0065 - val_loss: 0.0044
# Epoch 53/100
# 44/44 [==============================] - 1s 28ms/step - loss: 0.0063 - val_loss: 0.0045
# Epoch 54/100
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0066 - val_loss: 0.0044
# Epoch 55/100
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0065 - val_loss: 0.0045
# Epoch 56/100
# 44/44 [==============================] - 1s 30ms/step - loss: 0.0065 - val_loss: 0.0046
# Epoch 57/100
# 44/44 [==============================] - 1s 28ms/step - loss: 0.0064 - val_loss: 0.0044
# Epoch 58/100
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0064 - val_loss: 0.0050
# Epoch 59/100
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0064 - val_loss: 0.0043
# Epoch 60/100
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0063 - val_loss: 0.0043
# Epoch 61/100
# 44/44 [==============================] - 2s 39ms/step - loss: 0.0062 - val_loss: 0.0044
# Epoch 62/100
# 44/44 [==============================] - 1s 33ms/step - loss: 0.0064 - val_loss: 0.0047
# Epoch 63/100
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0064 - val_loss: 0.0044
# Epoch 64/100
# 44/44 [==============================] - 1s 31ms/step - loss: 0.0064 - val_loss: 0.0044
# Epoch 65/100
# 44/44 [==============================] - 1s 31ms/step - loss: 0.0063 - val_loss: 0.0044
# Epoch 66/100
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0064 - val_loss: 0.0056
# Epoch 67/100
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0065 - val_loss: 0.0044
# Epoch 68/100
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0062 - val_loss: 0.0043
# Epoch 69/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0063 - val_loss: 0.0043
# Epoch 70/100
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0063 - val_loss: 0.0045
# Epoch 71/100
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0063 - val_loss: 0.0043
# Epoch 72/100
# 44/44 [==============================] - 1s 31ms/step - loss: 0.0062 - val_loss: 0.0043
# Epoch 73/100
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0060 - val_loss: 0.0043
# Epoch 74/100
# 44/44 [==============================] - 1s 34ms/step - loss: 0.0061 - val_loss: 0.0043
# Epoch 75/100
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0062 - val_loss: 0.0045
# Epoch 76/100
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0061 - val_loss: 0.0050
# Epoch 77/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0043
# Epoch 78/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0062 - val_loss: 0.0043
# Epoch 79/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0060 - val_loss: 0.0042
# Epoch 80/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0060 - val_loss: 0.0043
# Epoch 81/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0060 - val_loss: 0.0043
# Epoch 82/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0062 - val_loss: 0.0043
# Epoch 83/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0061 - val_loss: 0.0047
# Epoch 84/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0061 - val_loss: 0.0045
# Epoch 85/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0060 - val_loss: 0.0043
# Epoch 86/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0061 - val_loss: 0.0042
# Epoch 87/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0060 - val_loss: 0.0042
# Epoch 88/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0062 - val_loss: 0.0042
# Epoch 89/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0060 - val_loss: 0.0043
# Epoch 90/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0059 - val_loss: 0.0042
# Epoch 91/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0059 - val_loss: 0.0042
# Epoch 92/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0060 - val_loss: 0.0041
# Epoch 93/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0058 - val_loss: 0.0042
# Epoch 94/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0059 - val_loss: 0.0041
# Epoch 95/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0060 - val_loss: 0.0042
# Epoch 96/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0060 - val_loss: 0.0045
# Epoch 97/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0059 - val_loss: 0.0041
# Epoch 98/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0058 - val_loss: 0.0046
# Epoch 99/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0060 - val_loss: 0.0041
# Epoch 100/100
# 44/44 [==============================] - 1s 13ms/step - loss: 0.0060 - val_loss: 0.0041
# compilation time :  97.91074109077454

# %%
trainPredict = modelLSTM.predict(X_train)
testPredict = modelLSTM.predict(X_test)

trainPredict = sales_scaler.inverse_transform(trainPredict)
trainY = sales_scaler.inverse_transform([y_train])
testPredict = sales_scaler.inverse_transform(testPredict)
testY = sales_scaler.inverse_transform([y_test])

plot_predicted = testPredict.copy()
plot_predicted = plot_predicted.reshape(30, 1)
plot_actual = testY.copy()
plot_actual = plot_actual.reshape(30, 1)
print(plot_actual.shape)
print(plot_predicted.shape)
# Out:
# 51/51 [==============================] - 1s 5ms/step
# 1/1 [==============================] - 0s 27ms/step
# (30, 1)
# (30, 1)

# %%
plt.figure(figsize=(20,7))
plt.plot(pd.DataFrame(plot_predicted), label='Predicted')
plt.plot(pd.DataFrame(plot_actual), label='Actual')
plt.legend(loc='best')
plt.show()

# %%
plot_predicted = plot_predicted.reshape(30,)

forecastLSTM = pd.DataFrame({'test': test['sales'], 'forecast': plot_predicted}, index=test.index)
forecastLSTM
# Out:
#             test  forecast
# date
# 2017-07-17   258       260
# 2017-07-18   179       224
# 2017-07-19   256       234
# 2017-07-20   155       203
# 2017-07-21   332       214
# 2017-07-22   231       299
# 2017-07-23   323       252
# 2017-07-24   215       282
# 2017-07-25   231       229
# 2017-07-26   264       207
# 2017-07-27   125       211
# 2017-07-28   284       209
# 2017-07-29   259       307
# 2017-07-30   261       237
# 2017-07-31   210       270
# 2017-08-01   216       228
# 2017-08-02   225       208
# 2017-08-03   209       218
# 2017-08-04   303       180
# 2017-08-05   278       285
# 2017-08-06   253       251
# 2017-08-07   176       273
# 2017-08-08   214       225
# 2017-08-09   216       220
# 2017-08-10   199       217
# 2017-08-11   298       188
# 2017-08-12   214       275
# 2017-08-13   233       254
# 2017-08-14   203       233
# 2017-08-15   241       201

# %% [markdown]
# ##Facebook Prophet Model

# %%
trainP = train.copy()
trainP = trainP.reset_index()
trainP = trainP.rename(columns={'date': 'ds', 'sales': 'y'})

testP = test.copy()
testP = testP.reset_index()
testP = testP.rename(columns={'date': 'ds', 'sales': 'y'})

# %%
trainP.head()
# Out:
#           ds   y  onpromotion  dcoilwtico  year  month  day  dayofweek  lag_7  \
# 0 2013-02-06 179            0          96  2013      2    6          2    129
# 1 2013-02-07 150            0          96  2013      2    7          3    170
# 2 2013-02-08 189            0          96  2013      2    8          4    186
# 3 2013-02-09 202            0          97  2013      2    9          5    258
# 4 2013-02-10 191            0          97  2013      2   10          6    242
#
#    sales_mean_7
# 0           199
# 1           197
# 2           197
# 3           189
# 4           182

# %%
testP.head()
# Out:
#           ds   y  onpromotion  dcoilwtico  year  month  day  dayofweek  lag_7  \
# 0 2017-07-17 258            0          46  2017      7   17          0    199
# 1 2017-07-18 179            0          46  2017      7   18          1    201
# 2 2017-07-19 256            0          47  2017      7   19          2    190
# 3 2017-07-20 155            0          47  2017      7   20          3    179
# 4 2017-07-21 332           27          46  2017      7   21          4    357
#
#    sales_mean_7
# 0           240
# 1           237
# 2           247
# 3           243
# 4           240

# %%
model = Prophet()
model.fit(trainP)

future_dates = model.make_future_dataframe(periods=len(testP))
test_forecast = model.predict(future_dates)
future_dates
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpak6c538o/pj9pv0mt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpak6c538o/ndnte2xv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56878', 'data', 'file=/tmp/tmpak6c538o/pj9pv0mt.json', 'init=/tmp/tmpak6c538o/ndnte2xv.json', 'output', 'file=/tmp/tmpak6c538o/prophet_model09omvkqp/prophet_model-20240315095553.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:55:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:55:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#              ds
# 0    2013-02-06
# 1    2013-02-07
# 2    2013-02-08
# 3    2013-02-09
# 4    2013-02-10
# ...         ...
# 1643 2017-08-11
# 1644 2017-08-12
# 1645 2017-08-13
# 1646 2017-08-14
# 1647 2017-08-15
#
# [1648 rows x 1 columns]

# %%
# Combine actuals and forecasts for plotting
results = testP[['ds', 'y']].merge(test_forecast[['ds', 'yhat']], how='left', on='ds')
results.rename(columns={'y': 'test', 'yhat': 'forecast'}, inplace=True)

# Generate plot
plt.figure(figsize=(12, 6))
plt.plot(results['ds'], results['test'], label='test')
plt.plot(results['ds'], results['forecast'], label='forecast')
plt.legend()
plt.show()

# %%
results.set_index('ds')
# Out:
#             test  forecast
# ds
# 2017-07-17   258       204
# 2017-07-18   179       197
# 2017-07-19   256       206
# 2017-07-20   155       170
# 2017-07-21   332       258
# 2017-07-22   231       249
# 2017-07-23   323       268
# 2017-07-24   215       202
# 2017-07-25   231       195
# 2017-07-26   264       204
# 2017-07-27   125       168
# 2017-07-28   284       255
# 2017-07-29   259       246
# 2017-07-30   261       265
# 2017-07-31   210       199
# 2017-08-01   216       191
# 2017-08-02   225       200
# 2017-08-03   209       164
# 2017-08-04   303       251
# 2017-08-05   278       241
# 2017-08-06   253       260
# 2017-08-07   176       194
# 2017-08-08   214       186
# 2017-08-09   216       195
# 2017-08-10   199       159
# 2017-08-11   298       246
# 2017-08-12   214       237
# 2017-08-13   233       257
# 2017-08-14   203       190
# 2017-08-15   241       183

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

#MAPE
def mapeEv(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

model = [forecastSARIMAX, forecastLSTM, results]
model_name = ['SARIMAX', 'LSTM', 'FBProphet']
metrics = []

for i in range(len(model)):
    mae = mean_absolute_error(model[i]['test'], model[i]['forecast'])
    mse = mean_squared_error(model[i]['test'], model[i]['forecast'])
    rmse = np.sqrt(mse)
    mape = mapeEv(model[i]['test'], model[i]['forecast'])
    metrics.append([mae, mse, rmse, mape])

metrics = pd.DataFrame(metrics, columns=['MAE', 'MSE', 'RMSE', 'MAPE'], index=model_name)
metrics
# Out:
#            MAE   MSE  RMSE  MAPE
# SARIMAX     24   860    29    11
# LSTM        45 3,329    58    20
# FBProphet   32 1,360    37    14
